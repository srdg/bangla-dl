# %%
import cv2
import numpy as np
from collections import deque
from keras.models import load_model
from keras.preprocessing import image
from PIL import Image
import matplotlib.cm as cm
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
model = load_model('bangla-dl.h5')
cap = cv2.VideoCapture(0)
label_map = ['অ','আ','ই ','ঈ','উ','ঊ','ঋ','এ','ঐ','ও','ঔ',
             'ক','খ','গ','ঘ','ঙ',
             'চ','ছ','জ','ঝ','ঞ', 
             'ট','ঠ','ড','ঢ','ণ',
             'ত','থ','দ','ধ','ন',
             'প','ফ','ব','ভ','ম',
             'য','র','ল',
             'শ','ষ','স','হ',
             'য়','ড়','ঢ়','ৎ','ং','ঃ','ঁ']

while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Our operations on the frame come here
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    im = cv2.filter2D(gray, -1, kernel)
    thresh = 127
    im_bw = cv2.threshold(im, thresh, 255, cv2.THRESH_BINARY)[1]
    img = cv2.rectangle(im_bw,(0,0),(128,128),(0,255,0),3)
    imh = img[0:128,0:128]
    cv2.imshow('letter',imh)
    cv2.imshow('frame',im_bw)
    

    x = cv2.resize(imh, (32,32))
    x = np.expand_dims(x, axis=0)
    images = np.vstack([x])
    arr = np.array(images)[..., np.newaxis]
    classes = model.predict_classes(arr, batch_size=10)
    
    print(label_map[np.squeeze(classes)])
    cv2.putText(im_bw, label_map[np.squeeze(classes)], (140,0),cv2.FONT_HERSHEY_TRIPLEX, 4, (0, 0, 0), 2)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# ং
# ং
# ং
# ঞ
# আ
# আ
# আ
# আ
# ঋ
# অ
# অ
# অ
# অ
# অ
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# দ
# ং
# ং
# ং
# ং
# ং
# ং
# দ
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# দ
# দ
# দ
# ং
# দ
# দ
# দ
# দ
# ন
# দ
# দ
# ং
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# ং
# দ
# ং
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# দ
# ...
